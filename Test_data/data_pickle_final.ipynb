# %% [markdown]
# # Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import openpyxl
import pickle

# %%
ls
# Out:
#  Volume in drive G is New Volume
#  Volume Serial Number is AAA4-0BD0
#
#  Directory of G:\Sanit_Horizontal\Data Analysis\Dharin Project files\Friction Measurement Issues
#
# 16-12-2022  13:45    <DIR>          .
# 16-12-2022  13:45    <DIR>          ..
# 16-12-2022  11:51    <DIR>          .ipynb_checkpoints
# 16-12-2022  13:45        31,206,173 _30N_Vel.xlsx
# 14-12-2022  16:33        40,199,211 _40N_Vel.xlsx
# 16-12-2022  13:42        44,132,769 _50N_Vel.xlsx
# 16-12-2022  12:01        19,296,071 40N.pkl
# 16-12-2022  11:56        16,273,546 50N.pkl
# 15-12-2022  10:58           117,945 Data Input.ipynb
# 15-12-2022  18:14           540,849 Data Input_rev_15_12.ipynb
# 16-12-2022  09:56           496,030 Data Input_rev2_15_12.ipynb
# 16-12-2022  13:45            35,488 data_pickle_final.ipynb
# 16-12-2022  11:51            53,070 data_pickle_test.ipynb
# 15-12-2022  17:21            30,555 Untitled.ipynb
#               11 File(s)    152,381,707 bytes
#                3 Dir(s)  134,229,086,208 bytes free

# %% [markdown]
# # Worksheet Import

# %%
# Loading the Excel file 

dataframe = openpyxl.load_workbook("_30N_Vel.xlsx", data_only=True)

# %%
# Sheet names
sheet_names = dataframe.sheetnames

# %%
dict = {}

# %% [markdown]
# # Negative Value Removing Function

# %%
# Function for removing the negative values from datafarme

def neg_remove(df):
    
    a = list(df.keys())
    temp = df[df[a]>0]
    
    return temp

# %% [markdown]
# # Sheet Cleaning Function

# %%
def clean_sheet(df):
    
    temp = df
    print(temp.head())
    
    # Dropping Extra Columns
    df.drop(columns = df.columns[[0,1,2,-1]], axis = 1, inplace = True)
    
    # Renaming the columns for the convenience
    rename_columns = ['vel','T_cor','F_lever','T_SG','press','temp','pos']
    df.columns = rename_columns
    df.drop(index = 0, inplace = True)
    
    # Removing the negative values
    df = df.apply(neg_remove)
    df.dropna(axis = 0,inplace = True)
    
    # Resetting the index
    df.reset_index(inplace = True)
    df.drop(columns=df.columns[[0]],inplace = True)
    
    return df

# %% [markdown]
# # Loop for all the Sheets

# %%
for i in np.arange(0,len(sheet_names),1):
    
    # Getting the sheet name
    sheet = dataframe[sheet_names[i]]
    df = pd.DataFrame(sheet.values)
    
    # Cleaned sheet storage
    d = clean_sheet(df).to_dict()
    
    # Storing values in global pickle dictionary
    dict[sheet_names[i]] = d
# Out:
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  19.11.2022  09:00:52          0             -13.0648
# 3  2.0  19.11.2022  09:00:52     -0.007             -13.3859
# 4  3.0  19.11.2022  09:00:52    -0.0177             -13.5712
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                2.7467    -2.221                  0                  28.8049
# 3                2.4707   -2.2945                  0                   28.804
# 4                 2.308   -1.7605                  0                  28.8066
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0       2.9614
# 4           0.02       4.1111
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  19.11.2022  14:03:41     -0.391             -10.5937
# 3  2.0  19.11.2022  14:03:41    -0.3889             -10.8398
# 4  3.0  19.11.2022  14:03:41    -0.3615             -11.5143
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2               -3.8627   -1.7734                  0                  30.5806
# 3               -3.8533   -1.8967                  0                  30.5976
# 4                -0.952   -3.9154                  0                   30.579
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0      -3.0186
# 4           6.38      -1.7503
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  21.11.2022  15:42:26     -0.008             -12.9615
# 3  2.0  21.11.2022  15:42:26    -0.0036             -12.8669
# 4  3.0  21.11.2022  15:42:26    -0.0181             -12.7232
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                5.7053   -0.0581                  0                  40.1016
# 3                5.7907     1.288                  0                  40.1023
# 4                 5.924   -5.0874                  0                  40.1179
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0       6.6831
# 4           0.02       7.8473
#      0           1         2          3                    4   \
# 0   NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  65.0  21.11.2022  18:21:47     0.0085              52.8195
# 2  66.0  21.11.2022  18:21:47      0.063              58.9124
# 3  67.0  21.11.2022  18:21:47     0.1447              65.8896
# 4  68.0  21.11.2022  18:21:47     0.2345              70.2069
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                29.844   81.0306              7.854                  29.6369
# 2                29.908   83.5957              7.757                   29.637
# 3               29.8933   81.3532              7.805                  29.6352
# 4               29.8867   86.3945               7.82                  29.6441
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1          12.28           30
# 2          12.28           30
# 3          12.28           30
# 4          12.28           30
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  19.11.2022  14:45:11    -0.0599               5.7396
# 3  2.0  19.11.2022  14:45:11    -0.0599               7.5412
# 4  3.0  19.11.2022  14:45:11    -0.0599               8.4926
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2               29.9253   20.7688                  1                  31.0188
# 3               29.9573   17.4108                  1                  31.0224
# 4               29.9733   21.3658                  1                   31.008
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2          12.44           30
# 3          12.44           30
# 4          12.44           30
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  22.11.2022  08:33:20    -0.2514             -11.7278
# 3  2.0  22.11.2022  08:33:20    -0.2891             -12.0661
# 4  3.0  22.11.2022  08:33:20    -0.3007             -11.9291
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                 1.232   -7.1686               0.34                  26.3755
# 3                  1.22   -0.1665              0.328                  26.3727
# 4                1.3547   -2.4598               0.33                  26.3757
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0       1.3801
# 4           0.02       3.1702
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  22.11.2022  14:35:12    -0.0024             -12.3772
# 3  2.0  22.11.2022  14:35:12    -0.0149              -12.238
# 4  3.0  22.11.2022  14:35:12    -0.0226             -12.1909
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                4.4667   -0.7866                  0                  26.6294
# 3                4.4373   -0.4858                  0                  26.6218
# 4                 4.396   -0.4768                  0                  26.6221
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0       4.5332
# 4           0.02       5.6297
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  22.11.2022  22:38:48          0             -12.2511
# 3  2.0  22.11.2022  22:38:48          0             -12.2916
# 4  3.0  22.11.2022  22:38:48          0             -12.4343
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                 2.256   -0.6621                  0                  29.9407
# 3                2.2333   -0.9103                  0                  29.9327
# 4                 2.304   -0.6115                  0                  29.9443
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0            0
# 3              0       2.2664
# 4           0.02       3.7841
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  23.11.2022  09:04:39     -0.009             -12.4133
# 3  2.0  23.11.2022  09:04:40    -0.0022             -13.5156
# 4  3.0  23.11.2022  09:04:40     -0.003              -13.412
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                9.1213    0.0677              0.799                  27.4717
# 3                 9.796   -3.1774               1.01                  27.4684
# 4               10.2547   -2.7428              1.139                  27.4614
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2           6.08      27.5971
# 3           6.98      29.3524
# 4           7.66           30
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  23.11.2022  12:23:02          0             -12.5245
# 3  2.0  23.11.2022  12:23:03          0             -12.5225
# 4  3.0  23.11.2022  12:23:03          0             -12.5228
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                4.4587   -0.8251                  0                  29.3487
# 3                4.4253   -0.8197                  0                  29.3532
# 4                 4.416   -0.8206                  0                  29.3497
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2              0           50
# 3              0           50
# 4              0           50
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  23.11.2022  19:39:53    -0.0159              -1.4901
# 3  2.0  23.11.2022  19:39:53    -0.0178               1.6922
# 4  3.0  23.11.2022  19:39:53    -0.0567               7.6862
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2               29.5867   13.6962              7.806                  71.6466
# 3               29.5027   20.7172              7.951                  71.6302
# 4                29.548   26.9149              7.926                  71.6152
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2          10.38           30
# 3           10.4           30
# 4          10.42           30
#     0           1         2          3                    4   \
# 0  NaN        Date      Time  v_act_kph  T_act_corr_filtered
# 1  0.0           0         0          0                    0
# 2  1.0  23.11.2022  21:03:31          0             -11.9278
# 3  2.0  23.11.2022  21:03:31          0             -11.9269
# 4  3.0  23.11.2022  21:03:31          0             -11.9284
#
#                      5         6                  7                        8   \
# 0  F_act_lever_filtered  T_act_SG  P_act_brake_fluid  t_act_infrared_filtered
# 1                     0         0                  0                        0
# 2                 12.72   -0.2154                  0                  27.1886
# 3               12.7293   -0.2176                  0                  27.1888
# 4               12.7507   -0.2254                  0                  27.1868
#
#               9            10
# 0  pos_servo_act  F_lever_set
# 1              0            0
# 2          26.98           30
# 3          26.98           30
# 4          26.98           30

# %% [markdown]
# # Saving the data in pickle format

# %%
f = open("30N.pkl","wb")

pickle.dump(dict,f)

# close file
f.close()
