# %%
ls
# Out:
#  Volume in drive G is New Volume
#  Volume Serial Number is AAA4-0BD0
#
#  Directory of G:\Sanit_Horizontal\Data Analysis\Dharin Project files\Friction Measurement Issues
#
# 26-12-2022  11:35    <DIR>          .
# 26-12-2022  11:35    <DIR>          ..
# 26-12-2022  11:35    <DIR>          .ipynb_checkpoints
# 18-12-2022  20:15        31,206,173 _30N_Vel.xlsx
# 18-12-2022  20:15        40,199,211 _40N_Vel.xlsx
# 18-12-2022  20:15        36,293,735 _50N_Vel.xlsx
# 19-12-2022  17:18           466,220 30N cleaner.ipynb
# 18-12-2022  20:15        17,990,829 30N.pkl
# 19-12-2022  17:19         6,042,869 30N_cycle_data.pkl
# 18-12-2022  20:15         8,536,764 30N_Od_removed.pkl
# 19-12-2022  17:18         6,049,478 30N_Od_removed_corrected.pkl
# 19-12-2022  16:59    <DIR>          30N_plots
# 18-12-2022  20:15        19,296,071 40N.pkl
# 19-12-2022  16:03         8,276,641 40N_cycle_data.pkl
# 18-12-2022  20:15         8,284,975 40N_Od_removed.pkl
# ...

# %% [markdown]
# # Plotting Function

# %%
def plotter(data):    
    
    
    # Setting the name of the file
    speed = data['vel'].max()
    force = data['F_lever'].max()

    # Initialise the subplot function using number of rows and columns
    figure, axis = plt.subplots(3, 2)

    # For Lever Force
    axis[0, 0].scatter(np.arange(0,len(data),1),data['F_lever'])
    axis[0, 0].set_title("Lever Force")

    # Lever Position
    axis[0, 1].scatter(np.arange(0,len(data),1),data['pos'])
    axis[0, 1].set_title("Lever Position")

    # For Fluid Pressure
    axis[1, 0].scatter(np.arange(0,len(data),1),data['press'])
    axis[1, 0].set_title("Fluid Pressure")

    # For Disc Temperature
    axis[1,1].scatter(np.arange(0,len(data),1),data['temp'])
    axis[1,1].set_title("Disc Temperature")

    # For Velocity
    axis[2,1].scatter(np.arange(0,len(data),1),data['vel'])
    axis[2,1].set_title("Velocity")
    
#     data['mu']

    # For Coefficient of Friction
    axis[2,0].scatter(np.arange(0,len(data),1),data['mu'])
    axis[2,0].set_title("COF")


    plt.suptitle(f'Lever force = {int(force)} N and Velocity = {int(speed)} kmph', fontsize=14)

    figure.tight_layout()

    # Combine all the operations and display
#     plt.savefig(f'30N_plots/{int(force)}_{int(speed)}.jpg',dpi=128)
    plt.show()

# %% [markdown]
# # Cycle Plot Function

# %%
def cycle_plot(data,i):


        # Setting the name of the file
        speed = data['vel'].max()
        force = data['F_lever'].max()

        # Initialise the subplot function using number of rows and columns
        figure, axis = plt.subplots(3, 2)

        # For Lever Force
        axis[0, 0].scatter(np.arange(0,len(data),1),data['F_lever'])
        axis[0, 0].set_title("Lever Force")

        # Lever Position
        axis[0, 1].scatter(np.arange(0,len(data),1),data['pos'])
        axis[0, 1].set_title("Lever Position")

        # For Fluid Pressure
        axis[1, 0].scatter(np.arange(0,len(data),1),data['press'])
        axis[1, 0].set_title("Fluid Pressure")

        # For Disc Temperature
        axis[1, 1].scatter(np.arange(0,len(data),1),data['temp'])
        axis[1,1].set_title("Disc dataerature")

        # For Velocity
        axis[2, 1].scatter(np.arange(0,len(data),1),data['vel'])
        axis[2,1].set_title("Velocity")

        # For Coefficient of Friction
        axis[2, 0].scatter(np.arange(0,len(data),1),data['mu'])
        axis[2,0].set_title("COF")

        plt.suptitle(f'Lever force = {int(force)} N and Velocity = {int(speed)} kmph for Cycle = {i+1}', fontsize=14)

        figure.tight_layout()
        
        str = f'{int(force)}N' +'_'+ f'{int(speed)}kmph' + f'_C{i+1}'
        
        # Combine all the operations and display
#         plt.savefig(f'{str}.jpg',dpi=128)

        # Combine all the operations and display
        plt.show()

# %% [markdown]
# # Nested Key Printer

# %%
def nest_key(d, indent=0):
    
    for key, value in d.items():
        
        
        
        if isinstance(value, dict):
            
            print('\t' * indent + f'{key}')
            
            nest_key(value, indent+1)
            
#         else:
#             print('\t' * (indent+1) + str(value))

# %% [markdown]
# # Data Input

# %%
temp = pd.read_pickle('50N_cycle_data.pkl')

# %%
final_dict = temp

# %%
nest_key(temp)
# Out:
# 1kmph
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# 1.5kmph
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# 3kmph
# 	C1
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C2
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 4kmph
# 	C1
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C2
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C3
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C4
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C5
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 5kmph
# 	C1
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C2
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 6kmph
# 	C1
# 		vel
# 		T_cor
# 		F_lever
# 		T_SG
# 		press
# 		temp
# 		pos
# 		mu
# 	C2
# 		vel
# 		T_cor
# ...

# %%
type(final_dict)
# Out:
# dict

# %%
data = pd.DataFrame(temp['3kmph']['C1'])

# %%
data.head()
# Out:
#       vel     T_cor  F_lever      T_SG   press     temp    pos        mu
# 0  2.9733  213.6067  50.0040  228.8721  16.435  31.4874  14.32  0.415737
# 1  3.0259  206.8642  49.9493  218.4621  16.152  31.4428  14.32  0.403780
# 2  3.0247  206.7184  49.9400  219.2422  16.102  31.4569  14.32  0.406480
# 3  2.9469  212.2266  49.9493  228.8338  16.463  32.0563  14.32  0.414960
# 4  3.0123  212.2077  49.9613  228.5732  16.485  32.0629  14.34  0.413934

# %%
plotter(data)

# %%
data.drop(index =data[2000:].index, axis = 0, inplace = True)

# %%
plotter(data)

# %%
final_dict['3kmph'].update({'C1': data.to_dict()})

# %%
plotter(pd.DataFrame(final_dict['3kmph']['C1']))

# %%
data = pd.DataFrame(temp['3kmph']['C2'])

# %%
plotter(data)

# %%
data.drop(index =data[2000:].index, axis = 0, inplace = True)

# %%
plotter(data)

# %%
final_dict['3kmph'].update({'C2': data.to_dict()})

# %%
plotter(pd.DataFrame(final_dict['3kmph']['C2']))

# %%
plotter(pd.DataFrame(final_dict['7kmph']['C3']))

# %%
del(final_dict['7kmph']['C3'])

# %%
nest_key(final_dict['7kmph'])
# Out:
# C1
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C2
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu

# %%
del(final_dict['8kmph']['C4'])

# %%
nest_key(final_dict['8kmph'])
# Out:
# C1
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C2
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C3
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu

# %%
data = pd.DataFrame(temp['20kmph']['C3'])

# %%
plotter(data)

# %%
data.drop(index =data[1800:].index, axis = 0, inplace = True)

# %%
plotter(data)

# %%
final_dict['20kmph'].update({'C3': data.to_dict()})

# %%
plotter(pd.DataFrame(final_dict['20kmph']['C3']))

# %%
final_dict['20kmph'].update({'C3': pd.DataFrame(final_dict['20kmph']['C3']).reset_index().to_dict()})

# %%
final_dict['20kmph']['C3']
# Out:
# {'index': {0: 2779,
#   1: 2780,
#   2: 2781,
#   3: 2782,
#   4: 2783,
#   5: 2784,
#   6: 2785,
#   7: 2786,
#   8: 2787,
#   9: 2788,
#   10: 2789,
#   11: 2790,
#   12: 2791,
#   13: 2792,
#   14: 2793,
#   15: 2794,
#   16: 2795,
#   17: 2796,
#   18: 2797,
#   19: 2798,
#   20: 2799,
#   21: 2800,
#   22: 2801,
#   23: 2802,
#   24: 2803,
#   25: 2804,
#   26: 2805,
#   27: 2806,
#   28: 2807,
#   29: 2808,
#   30: 2809,
#   31: 2810,
#   32: 2811,
#   33: 2812,
#   34: 2813,
#   35: 2814,
#   36: 2815,
#   37: 2816,
#   38: 2817,
#   39: 2818,
#   40: 2819,
#   41: 2820,
#   42: 2821,
#   43: 2822,
#   44: 2823,
#   45: 2824,
#   46: 2825,
#   47: 2826,
#   48: 2827,
#   49: 2828,
#   50: 2829,
#   51: 2830,
#   52: 2831,
#   53: 2832,
#   54: 2833,
#   55: 2834,
#   56: 2835,
#   57: 2836,
#   58: 2837,
#   59: 2838,
#   60: 2839,
#   61: 2840,
#   62: 2841,
#   63: 2842,
#   64: 2843,
#   65: 2844,
#   66: 2845,
#   67: 2846,
#   68: 2847,
#   69: 2848,
#   70: 2849,
# ...

# %%
nest_key(final_dict['20kmph']['C3'])
# Out:
# index
# vel
# T_cor
# F_lever
# T_SG
# press
# temp
# pos
# mu

# %%
del(final_dict['20kmph']['C3']['index'])

# %%
final_dict['20kmph']['C3']
# Out:
# {'vel': {0: 19.9578,
#   1: 20.0333,
#   2: 20.0231,
#   3: 20.0188,
#   4: 19.978,
#   5: 19.9648,
#   6: 20.0558,
#   7: 19.9726,
#   8: 19.9998,
#   9: 20.0364,
#   10: 19.9722,
#   11: 19.9579,
#   12: 20.0673,
#   13: 19.9942,
#   14: 19.9858,
#   15: 19.9832,
#   16: 20.0402,
#   17: 19.9573,
#   18: 20.0302,
#   19: 20.0281,
#   20: 19.9809,
#   21: 19.9668,
#   22: 20.002,
#   23: 19.9837,
#   24: 20.0339,
#   25: 20.0532,
#   26: 19.98,
#   27: 20.0528,
#   28: 20.0061,
#   29: 19.9633,
#   30: 20.0023,
#   31: 19.9902,
#   32: 19.9712,
#   33: 20.0898,
#   34: 20.0038,
#   35: 19.9672,
#   36: 20.0337,
#   37: 19.9701,
#   38: 19.9764,
#   39: 20.056,
#   40: 19.9942,
#   41: 20.0236,
#   42: 19.9782,
#   43: 19.9897,
#   44: 20.0131,
#   45: 20.0156,
#   46: 20.0023,
#   47: 20.0331,
#   48: 19.9842,
#   49: 19.9635,
#   50: 20.0234,
#   51: 20.0338,
#   52: 19.9741,
#   53: 20.0422,
#   54: 20.0139,
#   55: 19.9781,
#   56: 20.0664,
#   57: 19.9645,
#   58: 19.9863,
# ...

# %%
key_list  = list(final_dict.keys())

# %%
for i in np.arange(2,len(key_list),1):
    
    cycle_list = list(final_dict[key_list[i]].keys())
    
    for j in np.arange(0,len(cycle_list),1):
    
#         print(j)
        # Setting up the dataframe
        data = pd.DataFrame(final_dict[key_list[i]][cycle_list[j]])
        data.reset_index(drop = True, inplace = True)
        
        # Plotting Function
        cycle_plot(data,j)

# %% [markdown]
# # Pickle File Export

# %%
import pickle

# %%
f = open("50N_cycle_omitted.pkl","wb")

pickle.dump(final_dict,f)

# close file
f.close()

# %%
nest_key(final_dict['4kmph'])
# Out:
# C1
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C2
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C3
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C4
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C5
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu

# %%
del(final_dict['4kmph']['C2'])

# %%
del(final_dict['4kmph']['C4'])

# %%
nest_key(final_dict['4kmph'])
# Out:
# C1
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C3
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu
# C5
# 	vel
# 	T_cor
# 	F_lever
# 	T_SG
# 	press
# 	temp
# 	pos
# 	mu

# %%
del(final_dict['5kmph']['C2'])

# %%
del(final_dict['8kmph']['C1'])

# %%
del(final_dict['6kmph']['C5'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [119], line 1
# ----> 1 del(final_dict['6kmph']['C5'])
#
# KeyError: 'C5'

# %%
del(final_dict['6kmph']['C2'])

# %%
del(final_dict['7kmph']['C2'])

# %%
f = open("50N_cycle_reg.pkl","wb")

pickle.dump(final_dict,f)

# close file
f.close()
